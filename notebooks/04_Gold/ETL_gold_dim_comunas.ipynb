-- %%
%sql

INSERT OVERWRITE proyecto_final.gold.dim_comunas(
  nro_comuna,
  perimetro_m,
  area_m2,
  coordenadas
)
SELECT DISTINCT 
  comuna_id, 
  perimetro_m, 
  area_m2,
  coordenadas
FROM proyecto_final.silver.comunas;
