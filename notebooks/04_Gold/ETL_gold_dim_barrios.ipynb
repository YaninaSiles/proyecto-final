-- %%
%sql

INSERT OVERWRITE proyecto_final.gold.dim_barrios(
  barrio_id_origen,
  barrio_nombre,
  perimetro_m,
  area_m2,
  coordenadas
)
SELECT 
  barrio_id, 
  barrio_nombre, 
  perimetro_m, 
  area_m2,
  coordenadas
FROM proyecto_final.silver.barrios;
