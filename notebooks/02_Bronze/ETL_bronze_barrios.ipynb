-- %%
%sql

INSERT OVERWRITE proyecto_final.raw.barrios_bronze
SELECT 
id,
objeto,
nombre,
comuna,
perimetro_,
area_metro,
geometry,
_rescued_data,
current_timestamp() as fecha_ingesta 
FROM read_files(
  '/Volumes/proyecto_final/raw/archivos/barrios.csv',
  format => 'csv',
  header => true
);
