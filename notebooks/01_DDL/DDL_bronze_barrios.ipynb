-- %%
%sql
DROP TABLE IF EXISTS proyecto_final.raw.barrios_bronze;

CREATE TABLE proyecto_final.raw.barrios_bronze
SELECT * FROM read_files(
  '/Volumes/proyecto_final/raw/archivos/barrios.csv',
  format => 'csv',
  header => true
);
