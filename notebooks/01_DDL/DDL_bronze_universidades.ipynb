-- %%
%sql

DROP TABLE IF EXISTS proyecto_final.raw.universidades_bronze;

CREATE TABLE proyecto_final.raw.universidades_bronze(
  id INT,
  nombre STRING,
  unidad_aca STRING,
  sede STRING,
  direccion STRING,
  barrio STRING,
  comuna STRING,
  telefono STRING,
  fax STRING,
  web STRING,
  geometry STRING,
  _rescued_data STRING,
  fecha_ingesta TIMESTAMP
)USING DELTA;
