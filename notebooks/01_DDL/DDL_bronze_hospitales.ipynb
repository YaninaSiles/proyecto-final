-- %%
%sql
DROP TABLE IF EXISTS proyecto_final.raw.hospitales_bronze;

CREATE TABLE proyecto_final.raw.hospitales_bronze(
  nombre_hospital STRING,
  nombre_funcional_completo STRING,
  nombre_generico STRING,
  especialidad STRING,
  tipo_atencion STRING,
  direccion STRING,
  barrio STRING,
  comuna INT,
  telefono STRING,
  sitio_web STRING,
  fuente_datos STRING,
  geometry STRING,
  fecha_ingesta TIMESTAMP
)USING DELTA;
