-- %%
%sql
DROP TABLE IF EXISTS proyecto_final.raw.comunas_bronze;

CREATE TABLE proyecto_final.raw.comunas_bronze(
  id INT,
  objeto STRING,
  comuna INT,
  barrios STRING,
  perimetro DOUBLE,
  area DOUBLE,
  geometry STRING,
  _rescued_data STRING,
  fecha_ingesta TIMESTAMP
) USING DELTA;
