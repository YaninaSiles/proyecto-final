-- %%
%sql
DROP TABLE IF EXISTS proyecto_final.raw.kioscos_bronze;

CREATE TABLE proyecto_final.raw.kioscos_bronze AS
SELECT 
  City,
  Name,
  Category,
  Address,
  Phone,
  Website,
  Email,
  Instagram,
  Facebook,
  Rating,
  `Reviews Count` AS Reviews_Count,
  Claimed,
  Attributes,
  `Top Review` AS Top_Review,
  `Working Hours` AS Working_Hours,
  `Image URL` AS Image_URL,
  Latitude,
  Longitude,
  `Google URL` AS Google_URL
FROM read_files(
  '/Volumes/proyecto_final/raw/archivos/kioscos_caba.csv',
  format => 'csv',
  header => true
);

SHOW TABLES IN proyecto_final.raw;
