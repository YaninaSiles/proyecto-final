-- %%
%sql
DROP TABLE IF EXISTS proyecto_final.raw.kioscos_bronze;

CREATE TABLE proyecto_final.raw.kioscos_bronze(
  city STRING,
  name STRING,
  category STRING,
  address STRING,
  phone STRING,
  website STRING,
  email STRING,
  instagram STRING,
  facebook STRING,
  rating STRING,
  reviews_count STRING,
  claimed STRING,
  attributes TIMESTAMP,
  top_Review STRING,
  working_Hours STRING,
  image_URL STRING,
  latitude DOUBLE,
  longitude DOUBLE,
  google_URL STRING,
  fecha_ingesta TIMESTAMP
)USING DELTA;
